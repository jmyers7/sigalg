# %% [markdown]
# # SigAlg's `integrate` method

# %%
# If running in Google Colab, uncomment the line below and run this cell first
# !pip install sigalg

# %% [markdown]
# The `integrate` method in SigAlg is a class method of the `Operators` class for computing *Lebesgue integrals* of random variables. The API reference for the method is [here](https://johnmyers-phd.com/sigalg/api/core/#sigalg.core.Operators.integrate){target="_blank"}, which includes precise mathematical definitions that we assume the reader knows. This notebook outlines a few usage examples.
#
# We begin by defining a sample space $\Omega = \{0,1,2,3,4\}$ and a probability measure $P$ on $\Omega$.
